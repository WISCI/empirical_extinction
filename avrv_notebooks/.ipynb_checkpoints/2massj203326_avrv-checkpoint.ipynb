# %%
import glob

import numpy as np
import scipy.optimize as op

import matplotlib.pyplot as plt

import astropy.units as u

import emcee

from measure_extinction.stardata import StarData
from measure_extinction.modeldata import ModelData
from measure_extinction.utils.fit_model import FitInfo

from measure_extinction.utils.fit_model import get_best_fit_params, get_percentile_params

from helpers import (plot_data_model, plot_data_model, comp_ext, plot_ext, 
                     get_fit_params, get_full_params, get_fit_params_g23only, get_full_params_g23only)

# %% [markdown]
# ## Info about the specific star and data to fit

# %% [markdown]
# Specify the location of the model and observed data

# %%
data_file_path = "/Users/jonty/Documents/GitHub/empirical_extinction/Targets/"
model_file_path = "/Users/jonty/Documents/GitHub/empirical_extinction/Models/"

# %% [markdown]
# Define star specific parameters

# %%
starname = "2massj203326"
fstarname = f"{starname}.dat"
velocity = 0.0   # assumption
relband = 0.55 * u.micron  # needed for dust extinction

# sptype and Teff, logg, from from Wei, C et al. (master thesis)
sptype = "O6V"
teff = 28900
teff_unc = 2000.0
logt = np.log10(teff)
logt_unc = 0.5 * (np.log10(teff + teff_unc) - np.log10(teff - teff_unc))
print(logt, logt_unc)
logg = 3.9
logg_unc = 0.1

# parameter names
pnames = ["logT","logg", "logZ", "Av","Rv","C2","C3","C4","x0","gamma","HI_gal","HI_mw","logf"]
# logZ and HI_mw not fit as sources in MW so HI_gal = HI_MW
pnames_fit = ["logT","logg", "Av","Rv","logf"]
fitparamsfunc = get_fit_params_g23only
fullparamsfunc = get_full_params_g23only
fit_range = "g23"

# initial starting position
params = [logt, logg, 0.0, 5.0, 3.1, 0.7, 3.23, 0.41, 4.59, 0.95, 20.5, 17.0, -1.0]

# add Gaussian priors based on prior knowledge
#ppriors = None
ppriors = {}
ppriors["logT"] = (logt, logt_unc)
ppriors["logg"] = (logg, logg_unc)
# Out:
# 4.460897842756548 0.0301030997112135

# %% [markdown]
# Give the fitting parameters

# %%
# emcee
nsteps = 5000

# %% [markdown]
# Read in the star data

# %%
# get the observed reddened star data
reddened_star = StarData(fstarname, path=f"{data_file_path}")
band_names = reddened_star.data["BAND"].get_band_names()
for ckey in list(reddened_star.data.keys()):
    if ckey not in ["BAND", "STIS_Opt"]:
        del reddened_star.data[ckey]
    else:
        # add in 1% unc
        gvals = reddened_star.data[ckey].npts > 0
        reddened_star.data[ckey].uncs[gvals] += 0.01 * reddened_star.data[ckey].fluxes[gvals]
data_names = reddened_star.data.keys()
print(data_names)
# Out:
# dict_keys(['BAND', 'STIS_Opt'])

# %% [markdown]
# Create the weight arrays based on the observed uncertainties and exclude regions that have known lines not fit by the models (ISM gas, etc.).

# %%
# cropping info for weights
#  bad regions are defined as those were we know the models do not work
#  or the data is bad
ex_regions = [
    [8.23 - 0.1, 8.23 + 0.1],  # geocoronal line
    [8.7, 10.0],  # bad data from STIS
    [3.55, 3.6],
    [3.80, 3.90],
    [4.15, 4.3],
    [6.4, 6.6],
    [7.1, 7.3],
    [7.45, 7.55],
    [7.65, 7.75],
    [7.9, 7.95],
    [8.05, 8.1],
] / u.micron

weights = {}
for cspec in data_names:
    weights[cspec] = np.full(len(reddened_star.data[cspec].fluxes), 0.0)
    gvals = reddened_star.data[cspec].npts > 0

    weights[cspec][gvals] = 1.0 / reddened_star.data[cspec].uncs[gvals].value

    x = 1.0 / reddened_star.data[cspec].waves
    for cexreg in ex_regions:
        weights[cspec][np.logical_and(x >= cexreg[0], x <= cexreg[1])] = 0.0

# %% [markdown]
# Get the model data

# %%
tlusty_models_fullpath = glob.glob(f"{model_file_path}/tlusty_*v10.dat")
tlusty_models = [
    tfile[tfile.rfind("/") + 1 : len(tfile)] for tfile in tlusty_models_fullpath
]

# get the models with just the reddened star band data and spectra
modinfo = ModelData(
    tlusty_models,
    path=f"{model_file_path}",
    band_names=band_names,
    spectra_names=data_names,
)

# %% [markdown]
# Setup the fit parameters

# %%
# not all these parameters are being fit
#   not fitting for met, log(HI) MW foreground
plimits = [
        [modinfo.temps_min, modinfo.temps_max],  # log(Teff)
        [modinfo.gravs_min, modinfo.gravs_max],  # log(g)
        [0.0, 0.0], # met
        [0.0, 10.0],   # Av
        [2.31, 5.59],   # Rv
        [-0.1, 5.0],  # C2
        [-1.0, 6.0],   # C3
        [-0.5, 1.5],   # C4
        [4.5, 4.9],   # xo
        [0.6, 1.5],   # gamma
        [18.0, 24.0], # log(HI) internal to galaxy
        [17.0, 22.0], # log(HI) MW foreground
        [-9.0,9.0], #logf nuisance factor
    ]

print(plimits)
# Out:
# [[4.176091259055681, 4.740362689494244], [1.75, 4.75], [0.0, 0.0], [0.0, 10.0], [2.31, 5.59], [-0.1, 5.0], [-1.0, 6.0], [-0.5, 1.5], [4.5, 4.9], [0.6, 1.5], [18.0, 24.0], [17.0, 22.0], [-9.0, 9.0]]

# %% [markdown]
# Package the fit info needed.  FitInfo class defines the likelihood functions as well.

# %%
fitinfo = FitInfo(
    pnames,
    plimits,
    weights,
    parameter_priors=ppriors,
    stellar_velocity=velocity,
)

# %%
# check that the initial starting position returns a valid value of lnprob and is within the parameter bounds
fitinfo.check_param_limits(params)
print(fitinfo.lnlike(params, reddened_star, modinfo))
print(fitinfo.lnprior(params))
print(fitinfo.lnprob(params, reddened_star, modinfo, fitinfo))
# Out:
# 38288.88964834829
# 0.0
# 38288.88964834829

# %% [markdown]
# ## Do the fitting to find the best fit (using a minimizer)

# %%
# simple function to turn the log(likelihood) into the chisqr
#  requied as op.minimize function searchs for the minimum chisqr (not max likelihood like MCMC algorithms)
def nll(params, *args):
    full_params = fullparamsfunc(params)
    return -fitinfo.lnprob(full_params, *args, fit_range=fit_range)

init_fit_params = fitparamsfunc(params)

# run the fit
result = op.minimize(
    nll, init_fit_params, method="Nelder-Mead", options={"maxiter": 10000}, 
    args=(reddened_star, modinfo, fitinfo)
)

# check the fit output
print(result["message"])
# Out:
# Optimization terminated successfully.

# %%
# print results
params_best = result["x"]

# print the best fit
for k, val in enumerate(params_best):
    print(f"{val} # {pnames_fit[k]}")
# Out:
# 4.740362390532698 # logT
# 4.500000221592519 # logg
# 6.707808876400248 # Av
# 3.0940210986517442 # Rv
# -1.9083136781268304 # logf

# %% [markdown]
# Plot the spectra with the best fit model

# %%
# plot optimizer/minimizer best fit
plot_data_model(reddened_star, weights, modinfo, params_best, pnames_fit, starname, velocity,
                prange=[1e-16, 1e-10], fullparamsfunc=fullparamsfunc, fit_range=fit_range)

# %% [markdown]
# ###### Run emcee MCMC sampler to define uncertainties (bonus section)

# %%
p0 = params_best
ndim = len(p0)

print(p0)

#p0 = [4.5,4.0,6.71,3.1,-1.9]

def lnprob_mcmc(params, *args):
    full_params = fullparamsfunc(params)
    return fitinfo.lnprob(full_params, *args, fit_range=fit_range)

nwalkers = 10 * ndim

# setting up the walkers to start "near" the inital guess
p = [p0 * (1 + 0.0001 * np.random.normal(0, 1.0, ndim)) for k in range(nwalkers)]

for i in range(nwalkers):
    for j in range(ndim):
        if p[i][j] < plimits[j][0] or p[i][j] > plimits[j][1] :
            print(pnames[j], p[i][j] ,plimits[j][:])

# setup the sampler
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, lnprob_mcmc, args=(reddened_star, modinfo, fitinfo)
)

# do the full sampling
pos, prob, state = sampler.run_mcmc(p, nsteps, progress=True)
# Out:
# [ 4.74036239  4.50000022  6.70780888  3.0940211  -1.90831368]
# logT 4.74055271158519 [4.176091259055681, 4.740362689494244]
# logZ 6.707695776788821 [0.0, 0.0]
# Rv -1.9083964498210304 [2.31, 5.59]
# logZ 6.708014186415789 [0.0, 0.0]
# Rv -1.9085380359947648 [2.31, 5.59]
# logZ 6.7072377559401755 [0.0, 0.0]
# Rv -1.9085085306401997 [2.31, 5.59]
# logT 4.7406870216036765 [4.176091259055681, 4.740362689494244]
# logZ 6.707028776422461 [0.0, 0.0]
# Rv -1.9086013149081071 [2.31, 5.59]
# logZ 6.706561527358257 [0.0, 0.0]
# Rv -1.9083827530151458 [2.31, 5.59]
# logT 4.7407658926976906 [4.176091259055681, 4.740362689494244]
# logZ 6.707585735540868 [0.0, 0.0]
# Rv -1.9082760926795541 [2.31, 5.59]
# logZ 6.707380772440036 [0.0, 0.0]
# Rv -1.9081837446031806 [2.31, 5.59]
# logZ 6.707422365103817 [0.0, 0.0]
# Rv -1.9080941535901979 [2.31, 5.59]
# logT 4.741259980307531 [4.176091259055681, 4.740362689494244]
# logZ 6.708358825496262 [0.0, 0.0]
# Rv -1.9080287471980117 [2.31, 5.59]
# logT 4.740554304888289 [4.176091259055681, 4.740362689494244]
# logZ 6.707694157174733 [0.0, 0.0]
# Rv -1.908320196148583 [2.31, 5.59]
# logT 4.740952213002669 [4.176091259055681, 4.740362689494244]
# logZ 6.707169322211037 [0.0, 0.0]
# Rv -1.907643661315819 [2.31, 5.59]
# logT 4.740491557987429 [4.176091259055681, 4.740362689494244]
# logZ 6.7080898307296595 [0.0, 0.0]
# Rv -1.9085730214487409 [2.31, 5.59]
# logZ 6.707813042031467 [0.0, 0.0]
# Rv -1.9084249409600904 [2.31, 5.59]
# logZ 6.707718271246906 [0.0, 0.0]
# Rv -1.9087140063138797 [2.31, 5.59]
# logT 4.740718400386506 [4.176091259055681, 4.740362689494244]
# logZ 6.7075996102705115 [0.0, 0.0]
# Rv -1.908542277039429 [2.31, 5.59]
# logZ 6.707481849420998 [0.0, 0.0]
# Rv -1.9085400964013204 [2.31, 5.59]
# logT 4.740877033367354 [4.176091259055681, 4.740362689494244]
# logZ 6.707667063119736 [0.0, 0.0]
# Rv -1.9084843320412894 [2.31, 5.59]
# logT 4.7413501780281635 [4.176091259055681, 4.740362689494244]
# logZ 6.708415349697342 [0.0, 0.0]
# Rv -1.9082684043217066 [2.31, 5.59]
# logT 4.740833702481061 [4.176091259055681, 4.740362689494244]
# logZ 6.708672601517807 [0.0, 0.0]
# Rv -1.9084808448798118 [2.31, 5.59]
# logZ 6.707368950895155 [0.0, 0.0]
# Rv -1.9079072516980435 [2.31, 5.59]
# logZ 6.7064167437679965 [0.0, 0.0]
# Rv -1.9085206325096078 [2.31, 5.59]
# logT 4.740835697445682 [4.176091259055681, 4.740362689494244]
# logZ 6.70835996982946 [0.0, 0.0]
# Rv -1.9084941628401426 [2.31, 5.59]
# logZ 6.708458522620274 [0.0, 0.0]
# Rv -1.9085025944629381 [2.31, 5.59]
# logZ 6.709000706955199 [0.0, 0.0]
# Rv -1.9084688496668605 [2.31, 5.59]
# logT 4.740543817401809 [4.176091259055681, 4.740362689494244]
# logZ 6.7067074371632724 [0.0, 0.0]
# Rv -1.9082178739158573 [2.31, 5.59]
# logZ 6.707746459255214 [0.0, 0.0]
# Rv -1.908355693542764 [2.31, 5.59]
# logT 4.740678906578297 [4.176091259055681, 4.740362689494244]
# logZ 6.707020785197016 [0.0, 0.0]
# Rv -1.908140698646421 [2.31, 5.59]
# logT 4.74111741149376 [4.176091259055681, 4.740362689494244]
# logZ 6.708181144231568 [0.0, 0.0]
# Rv -1.9081776863465592 [2.31, 5.59]
# logZ 6.707856189656009 [0.0, 0.0]
# Rv -1.9084760862347854 [2.31, 5.59]
# logT 4.740700852814118 [4.176091259055681, 4.740362689494244]
# logZ 6.708652584753603 [0.0, 0.0]
# Rv -1.9086105631879804 [2.31, 5.59]
# logZ 6.707870802254683 [0.0, 0.0]
# Rv -1.9082553563361393 [2.31, 5.59]
# logT 4.740788440258816 [4.176091259055681, 4.740362689494244]
# logZ 6.70737817275463 [0.0, 0.0]
# Rv -1.9084516084711238 [2.31, 5.59]
# logT 4.74066890160955 [4.176091259055681, 4.740362689494244]
# logZ 6.707834066221882 [0.0, 0.0]
# Rv -1.9085164943656663 [2.31, 5.59]
# logT 4.740895472961083 [4.176091259055681, 4.740362689494244]
# logZ 6.708886779050183 [0.0, 0.0]
# Rv -1.9086716390111287 [2.31, 5.59]
# logZ 6.708111080975977 [0.0, 0.0]
# Rv -1.9081892727600447 [2.31, 5.59]
# logZ 6.70893298043354 [0.0, 0.0]
# Rv -1.908240542474512 [2.31, 5.59]
# logZ 6.707583954333006 [0.0, 0.0]
# Rv -1.9082173832824831 [2.31, 5.59]
# logZ 6.708425169647549 [0.0, 0.0]
# Rv -1.908340945038035 [2.31, 5.59]
# logZ 6.708375618311023 [0.0, 0.0]
# Rv -1.9086465402757669 [2.31, 5.59]
# logT 4.7408646921820035 [4.176091259055681, 4.740362689494244]
# logZ 6.707401475168822 [0.0, 0.0]
# Rv -1.908614373483839 [2.31, 5.59]
# logT 4.740900001989181 [4.176091259055681, 4.740362689494244]
# logZ 6.707985457875419 [0.0, 0.0]
# Rv -1.9084553704315927 [2.31, 5.59]
# logZ 6.707329063607536 [0.0, 0.0]
# Rv -1.9085028197774412 [2.31, 5.59]
# logZ 6.707138907176706 [0.0, 0.0]
# Rv -1.9082225363728595 [2.31, 5.59]
# logZ 6.708555655927169 [0.0, 0.0]
# Rv -1.9081233741723664 [2.31, 5.59]
# logZ 6.707394093744536 [0.0, 0.0]
# Rv -1.9082774717421362 [2.31, 5.59]
# logZ 6.708991008134067 [0.0, 0.0]
# Rv -1.9086352218741305 [2.31, 5.59]
# logT 4.741089713101576 [4.176091259055681, 4.740362689494244]
# logZ 6.706013851825904 [0.0, 0.0]
# Rv -1.908365166045341 [2.31, 5.59]
# logT 4.74144309347934 [4.176091259055681, 4.740362689494244]
# logZ 6.707697597727165 [0.0, 0.0]
# Rv -1.9080986912767406 [2.31, 5.59]
# logZ 6.707982856247735 [0.0, 0.0]
# Rv -1.9082878539478034 [2.31, 5.59]
# logZ 6.707807129506361 [0.0, 0.0]
# Rv -1.9086758748232096 [2.31, 5.59]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 28
#      23 sampler = emcee.EnsembleSampler(
#      24     nwalkers, ndim, lnprob_mcmc, args=(reddened_star, modinfo, fitinfo)
#      25 )
#      27 # do the full sampling
# ---> 28 pos, prob, state = sampler.run_mcmc(p, nsteps, progress=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/emcee/ensemble.py:386, in EnsembleSampler.run_mcmc(self, initial_state, nsteps, **kwargs)
#     383     initial_state = self._previous_state
#     385 results = None
# --> 386 for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     387     pass
#     389 # Store so that the ``initial_state=None`` case will work
#
# File ~/anaconda3/lib/python3.10/site-packages/emcee/ensemble.py:287, in EnsembleSampler.sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress)
#     285     state.blobs = blobs0
#     286 if state.log_prob is None:
# --> 287     state.log_prob, state.blobs = self.compute_log_prob(state.coords)
#     288 if np.shape(state.log_prob) != (self.nwalkers,):
#     289     raise ValueError("incompatible input dimensions")
#
# File ~/anaconda3/lib/python3.10/site-packages/emcee/ensemble.py:458, in EnsembleSampler.compute_log_prob(self, coords)
#     456 # Check for log_prob returning NaN.
#     457 if np.any(np.isnan(log_prob)):
# --> 458     raise ValueError("Probability function returned NaN")
#     460 return log_prob, blob
#
# ValueError: Probability function returned NaN

# %%
# create the samples variable for later use
flat_samples = sampler.get_chain(discard=int(0.8*nsteps), flat=True)

# get the best fit values
params_best = get_best_fit_params(sampler)

def get_percentile_params(samples):
    """
    Determine the 50p plus/minus 33p vlaues
    """

    per_params = map(
        lambda v: (v[1], v[2] - v[1], v[1] - v[0]),
        zip(*np.percentile(samples, [16, 50, 84], axis=0)),
    )

    return per_params

# get the 16, 50, and 84 percentiles
params_per = get_percentile_params(flat_samples)

# save the best fit and p50 +/- uncs values to a file
# save as a single row table to provide a uniform format
#f = open(out_basename + "_fit_params.dat", "w")
#f.write("# best fit, p50, +unc, -unc\n")
n_params = len(params_best)
params_p50 = np.zeros(n_params)
params_unc = np.zeros(n_params)
print("best p50 -munc +unc # paramname")
for k, val in enumerate(params_per):
    params_p50[k] = val[0]
    params_unc[k] = 0.5 * (val[1] + val[2])
    print(f"{params_best[k]:.3f} {val[0]:.3f} {val[1]:.3f} {val[2]:.3f} # {pnames_fit[k]}")

# %%
plot_data_model(reddened_star, weights, modinfo, params_best, pnames_fit, starname, velocity, 
                params_unc=params_unc, prange=[1e-16, 1e-10], fullparamsfunc=fullparamsfunc, fit_range=fit_range)

# %%
nparam = len(params_best)
fig, axes = plt.subplots(nparam, figsize=(10, 15), sharex=True)
samples = sampler.get_chain()
labels = pnames_fit
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");

# %%
import corner

fig = corner.corner(flat_samples, labels=labels)

# %% [markdown]
# ## Compute extinction and plot
#
# Calculate the E(B-V) = E(44 - 55), A(V), and R(V) from the computed extinction curve

# %%
extdata = comp_ext(modinfo, fullparamsfunc(params_best), velocity, reddened_star, relband, starname)
plot_ext(extdata, starname)
